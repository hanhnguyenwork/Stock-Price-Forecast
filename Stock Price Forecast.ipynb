# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Read data

# %%
df= pd.read_excel('C:/Users/Admin/Downloads/one (2).xlsx')
df.head()
# Out:
#          date code  basicPrice   open  close  high    low
# 0  2023-09-08  VCG       28.65  28.50  29.40  29.4  28.40
# 1  2023-09-08  FCN       17.60  17.60  17.55  17.8  17.40
# 2  2023-09-08  HHV       15.90  15.85  15.90  16.2  15.80
# 3  2023-09-07  VCG       29.10  29.40  28.65  29.5  28.55
# 4  2023-09-07  FCN       17.10  17.60  17.60  18.1  17.50

# %%
df.dtypes
# Out:
# date           object
# code           object
# basicPrice    float64
# open          float64
# close         float64
# high          float64
# low           float64
# dtype: object

# %%
#change type of column from object to datetime
df['date'] = pd.to_datetime(df['date'],format='%Y%m%d')

df = df.sort_values(by='date')

# %% [markdown]
# Read each stock

# %%
VCG = df[df['code'] == 'VCG']
VCG.head()
# Out:
#            date code  basicPrice  open  close  high  low
# 7470 2013-01-02  VCG         8.5   8.6    9.0   9.0  8.5
# 7468 2013-01-03  VCG         9.0   9.0    8.6   9.1  8.5
# 7466 2013-01-04  VCG         8.7   8.7    9.2   9.3  8.4
# 7464 2013-01-07  VCG         9.2   9.2    8.8   9.3  8.8
# 7462 2013-01-08  VCG         8.9   8.8    9.1   9.4  8.6

# %%
FCN = df[df['code'] == 'FCN']
FCN.head()
# Out:
#            date code  basicPrice  open  close  high   low
# 7471 2013-01-02  FCN        17.7  18.0   17.9  18.2  17.7
# 7469 2013-01-03  FCN        17.9  17.8   17.4  17.9  17.3
# 7467 2013-01-04  FCN        17.4  17.6   17.5  17.8  17.4
# 7465 2013-01-07  FCN        17.5  17.5   17.4  17.8  17.4
# 7463 2013-01-08  FCN        17.4  17.4   17.9  18.0  17.4

# %%
HHV = df[df['code'] == 'HHV']
HHV.head()
# Out:
#            date code  basicPrice  open  close  high   low
# 6000 2015-12-18  HHV        10.5  10.5   10.5  10.5  10.5
# 5998 2015-12-21  HHV        10.5  14.7   14.7  14.7  14.7
# 5995 2015-12-22  HHV        14.7  14.7   14.7  14.7  14.7
# 5991 2015-12-23  HHV        14.7  14.7   14.7  14.7  14.7
# 5988 2015-12-24  HHV        14.7  14.7   14.7  14.7  14.7

# %% [markdown]
# Data Exploratory

# %%
# Date range in the df_NYset
min_date = VCG['date'].min()
max_date = VCG['date'].max()

print("The farthest time is:" + str(min_date))
print("The nearest time is:" + str(max_date))


# Descriptive Statistics for Numerical Fields
numerical_stats = VCG[['basicPrice', 'open', 'close', 'high', 'low']].describe()
numerical_stats
# Out:
# The farthest time is:2013-01-02 00:00:00
# The nearest time is:2023-09-08 00:00:00
#         basicPrice         open        close         high          low
# count  2737.000000  2737.000000  2737.000000  2737.000000  2737.000000
# mean     22.008075    22.073292    22.065875    22.456175    21.697662
# std      10.981734    10.945301    10.934318    11.067110    10.794670
# min       0.000000     7.200000     7.400000     7.700000     6.900000
# 25%      13.400000    13.400000    13.400000    13.600000    13.200000
# 50%      19.400000    19.650000    19.500000    20.000000    19.200000
# 75%      26.400000    26.400000    26.400000    26.600000    26.150000
# max      56.000000    56.000000    56.000000    57.600000    55.300000

# %%
# Date range in the df_NYset
min_date = FCN['date'].min()
max_date = FCN['date'].max()

print("The farthest time is:" + str(min_date))
print("The nearest time is:" + str(max_date))


# Descriptive Statistics for Numerical Fields
numerical_stats = FCN[['basicPrice', 'open', 'close', 'high', 'low']].describe()
numerical_stats
# Out:
# The farthest time is:2013-01-02 00:00:00
# The nearest time is:2023-09-08 00:00:00
#         basicPrice         open        close         high          low
# count  2737.000000  2737.000000  2737.000000  2737.000000  2737.000000
# mean     17.444099    17.495667    17.476690    17.792952    17.223003
# std       5.103922     5.055246     5.050583     5.148012     4.973164
# min       0.000000     5.790000     6.220000     6.300000     5.790000
# 25%      13.700000    13.750000    13.700000    13.950000    13.500000
# 50%      17.150000    17.150000    17.150000    17.500000    16.900000
# 75%      21.300000    21.300000    21.300000    21.600000    21.000000
# max      36.000000    36.300000    36.000000    37.000000    33.500000

# %%
# Date range in the df_NYset
min_date = HHV['date'].min()
max_date = HHV['date'].max()

print("The farthest time is:" + str(min_date))
print("The nearest time is:" + str(max_date))


# Descriptive Statistics for Numerical Fields
numerical_stats = HHV[['basicPrice', 'open', 'close', 'high', 'low']].describe()
numerical_stats
# Out:
# The farthest time is:2015-12-18 00:00:00
# The nearest time is:2023-09-08 00:00:00
#         basicPrice         open        close         high          low
# count  1998.000000  1998.000000  1998.000000  1998.000000  1998.000000
# mean     13.448348    13.489294    13.490626    13.618509    13.370175
# std       4.388255     4.336543     4.343214     4.468057     4.221035
# min       0.000000     4.000000     4.000000     4.000000     4.000000
# 25%      10.512500    10.700000    10.600000    10.700000    10.500000
# 50%      12.000000    12.000000    12.000000    12.000000    12.000000
# 75%      16.100000    16.100000    16.100000    16.200000    16.000000
# max      27.900000    28.250000    28.100000    28.600000    27.900000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the visualization
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))

# Plotting distributions of numerical columns
for i, column in enumerate(['basicPrice', 'open', 'close', 'high', 'low']):
    plt.subplot(2, 3, i+1)
    sns.histplot(VCG[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show();
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the visualization
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))

# Plotting distributions of numerical columns
for i, column in enumerate(['basicPrice', 'open', 'close', 'high', 'low']):
    plt.subplot(2, 3, i+1)
    sns.histplot(FCN[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show();
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the visualization
sns.set(style="whitegrid")
plt.figure(figsize=(15, 10))

# Plotting distributions of numerical columns
for i, column in enumerate(['basicPrice', 'open', 'close', 'high', 'low']):
    plt.subplot(2, 3, i+1)
    sns.histplot(HHV[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show();
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.set(style="whitegrid")

# Trend analysis: Plotting the basic price over time
plt.figure(figsize=(12, 6))
plt.plot(FCN['date'], FCN['close'], label='close', color='blue')
plt.title('Trend of close Prices FCN')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# Volatility analysis: High-Low Price Spread
FCN['price_spread'] = FCN['high'] - FCN['low']
plt.figure(figsize=(12, 6))
plt.plot(FCN['date'], FCN['price_spread'], label='Price Spread (High-Low)', color='blue')
plt.title('Volatility Prices (High-Low Spread) of FCN')
plt.xlabel('Date')
plt.ylabel('Price Spread')
plt.legend()
plt.show()

# Correlation
correlation_matrix = FCN[['basicPrice', 'open', 'close', 'high', 'low']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of of FCN')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2924\2528470678.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FCN['price_spread'] = FCN['high'] - FCN['low']

# %%
sns.set(style="whitegrid")

# Trend analysis: Plotting the basic price over time
plt.figure(figsize=(12, 6))
plt.plot(VCG['date'], VCG['close'], label='close', color='blue')
plt.title('Trend of close Prices VCG')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# Volatility analysis: High-Low Price Spread
VCG['price_spread'] = VCG['high'] - VCG['low']
plt.figure(figsize=(12, 6))
plt.plot(VCG['date'], VCG['price_spread'], label='Price Spread (High-Low)', color='blue')
plt.title('Volatility Prices (High-Low Spread) of VCG')
plt.xlabel('Date')
plt.ylabel('Price Spread')
plt.legend()
plt.show()

# Correlation
correlation_matrix = VCG[['basicPrice', 'open', 'close', 'high', 'low']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of of VCG')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2924\3242770971.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   VCG['price_spread'] = VCG['high'] - VCG['low']

# %%
sns.set(style="whitegrid")

# Trend analysis: Plotting the basic price over time
plt.figure(figsize=(12, 6))
plt.plot(HHV['date'], HHV['close'], label='close', color='blue')
plt.title('Trend of close Prices HHV')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# Volatility analysis: High-Low Price Spread
HHV['price_spread'] = HHV['high'] - HHV['low']
plt.figure(figsize=(12, 6))
plt.plot(HHV['date'], HHV['price_spread'], label='Price Spread (High-Low)', color='blue')
plt.title('Volatility Prices (High-Low Spread) of HHV')
plt.xlabel('Date')
plt.ylabel('Price Spread')
plt.legend()
plt.show()

# Correlation
correlation_matrix = HHV[['basicPrice', 'open', 'close', 'high', 'low']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of of HHV')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2924\1653089371.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   HHV['price_spread'] = HHV['high'] - HHV['low']

# %%
HHV.set_index(HHV['date'], inplace=True)
HHV.head()
# Out:
#                  date code  basicPrice  open  close  high   low  price_spread
# date
# 2015-12-18 2015-12-18  HHV        10.5  10.5   10.5  10.5  10.5           0.0
# 2015-12-21 2015-12-21  HHV        10.5  14.7   14.7  14.7  14.7           0.0
# 2015-12-22 2015-12-22  HHV        14.7  14.7   14.7  14.7  14.7           0.0
# 2015-12-23 2015-12-23  HHV        14.7  14.7   14.7  14.7  14.7           0.0
# 2015-12-24 2015-12-24  HHV        14.7  14.7   14.7  14.7  14.7           0.0

# %% [markdown]
# Dự báo mô hình Arima

# %%
from statsmodels.tsa.stattools import adfuller

# Function to perform Augmented Dickey-Fuller test
def test_stationarity(timeseries):
    # Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    return dfoutput

# Applying the test on the 'basicPrice' column
adf_test_result = test_stationarity(HHV['basicPrice'])
adf_test_result
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -2.310315
# p-value                           0.168663
# #Lags Used                        9.000000
# Number of Observations Used    1988.000000
# Critical Value (1%)              -3.433644
# Critical Value (5%)              -2.862995
# Critical Value (10%)             -2.567545
# dtype: float64

# %%
from statsmodels.tsa.arima.model import ARIMA
from pandas.plotting import autocorrelation_plot
import itertools
import warnings

# Function to find the best ARIMA parameters
def find_best_arima(series, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    for p, d, q in itertools.product(p_values, d_values, q_values):
        try:
            model = ARIMA(series, order=(p, d, q))
            model_fit = model.fit()
            aic = model_fit.aic
            if aic < best_score:
                best_score, best_cfg = aic, (p, d, q)
            print('ARIMA({}, {}, {}) AIC={}'.format(p, d, q, aic))
        except:
            continue
    return best_cfg

# Define the p, d, q ranges to test
p_range = range(0, 3) # typically 0-2
d_range = range(0, 2) # 0 or 1 since we already know series is stationary
q_range = range(0, 3) # typically 0-2

# Ignoring warning messages to keep the output clean
warnings.filterwarnings("ignore")

# Find the best ARIMA parameters
best_arima_params = find_best_arima(HHV['basicPrice'], p_range, d_range, q_range)
best_arima_params
# Out:
# ARIMA(0, 0, 0) AIC=11582.889287244214
# ARIMA(0, 0, 1) AIC=9423.721146052285
# ARIMA(0, 0, 2) AIC=8068.006874025792
# ARIMA(0, 1, 0) AIC=5015.465781037875
# ARIMA(0, 1, 1) AIC=4918.8845710619225
# ARIMA(0, 1, 2) AIC=4916.446464493796
# ARIMA(1, 0, 0) AIC=5005.8588589371075
# ARIMA(1, 0, 1) AIC=4917.404345333686
# ARIMA(1, 0, 2) AIC=4916.1323861000965
# ARIMA(1, 1, 0) AIC=4928.896829068408
# ARIMA(1, 1, 1) AIC=4901.4894358999745
# ARIMA(1, 1, 2) AIC=4889.939512824709
# ARIMA(2, 0, 0) AIC=4925.6582763839915
# ARIMA(2, 0, 1) AIC=4905.219883946624
# ARIMA(2, 0, 2) AIC=4894.708866073893
# ARIMA(2, 1, 0) AIC=4924.210692474975
# ARIMA(2, 1, 1) AIC=4888.534981363515
# ARIMA(2, 1, 2) AIC=4889.743388881439
# (2, 1, 1)

# %%
# Fit the best ARIMA model
model = ARIMA(HHV['basicPrice'], order=(2, 1, 1))
model_fit = model.fit()
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:             basicPrice   No. Observations:                 1998
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -2440.267
# Date:                Fri, 29 Dec 2023   AIC                           4888.535
# Time:                        20:47:38   BIC                           4910.933
# Sample:                             0   HQIC                          4896.760
#                                - 1998
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6369      0.037     17.010      0.000       0.564       0.710
# ar.L2          0.1052      0.016      6.449      0.000       0.073       0.137
# ma.L1         -0.8800      0.037    -23.643      0.000      -0.953      -0.807
# ...

# %%
# Forecasting the next year (2023)
forecast_periods = 20 # Assuming daily df_NY for 12 days
forecast = model_fit.forecast(steps=forecast_periods)

HHV['Fitted'] = model_fit.predict()
HHV.tail(10)
# Out:
#                  date code  basicPrice   open  close   high    low  \
# date
# 2023-08-24 2023-08-24  HHV       14.40  14.55  14.70  14.70  14.35
# 2023-08-25 2023-08-25  HHV       14.70  14.70  14.80  15.10  14.70
# 2023-08-28 2023-08-28  HHV       14.80  14.85  14.80  14.90  14.70
# 2023-08-29 2023-08-29  HHV       14.80  14.85  14.85  15.15  14.85
# 2023-08-30 2023-08-30  HHV       14.85  14.95  14.95  15.05  14.80
# 2023-08-31 2023-08-31  HHV       14.95  15.05  15.25  15.50  15.05
# 2023-09-05 2023-09-05  HHV       15.25  15.60  15.60  15.75  15.40
# 2023-09-06 2023-09-06  HHV       15.60  15.60  15.60  15.60  15.35
# 2023-09-07 2023-09-07  HHV       15.60  15.80  15.90  16.20  15.80
# 2023-09-08 2023-09-08  HHV       15.90  15.85  15.90  16.20  15.80
#
#             price_spread     Fitted
# date
# 2023-08-24          0.35  14.547249
# 2023-08-25          0.40  14.534835
# 2023-08-28          0.20  14.745730
# 2023-08-29          0.30  14.847506
# ...

# %%
plt.plot(HHV['basicPrice'])
plt.plot(HHV['Fitted'])
plt.xlabel('Time')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.legend('basicPrice', 'fitted')

# %%
plt.plot(HHV['basicPrice'][1900:1998])
plt.plot(HHV['Fitted'][1900:1998])
plt.xlabel('Time')
plt.ylabel('Price')
plt.xticks(rotation=45, ha='right')
plt.legend('last', 'fitted')

# %%
print(model_fit.predict(start=1998, end = 2008, dynamic= True))
# Out:
# 1998    15.782015
# 1999    15.738442
# 2000    15.698274
# 2001    15.668106
# 2002    15.644665
# 2003    15.626561
# 2004    15.612563
# 2005    15.601743
# 2006    15.593379
# 2007    15.586913
# 2008    15.581914
# Name: predicted_mean, dtype: float64

# %% [markdown]
# Porfolio optimization

# %%
VCG.head()
# Out:
#            date code  basicPrice  open  close  high  low  price_spread
# 7470 2013-01-02  VCG         8.5   8.6    9.0   9.0  8.5           0.5
# 7468 2013-01-03  VCG         9.0   9.0    8.6   9.1  8.5           0.6
# 7466 2013-01-04  VCG         8.7   8.7    9.2   9.3  8.4           0.9
# 7464 2013-01-07  VCG         9.2   9.2    8.8   9.3  8.8           0.5
# 7462 2013-01-08  VCG         8.9   8.8    9.1   9.4  8.6           0.8

# %%
FCN.head()
# Out:
#            date code  basicPrice  open  close  high   low  price_spread
# 7471 2013-01-02  FCN        17.7  18.0   17.9  18.2  17.7           0.5
# 7469 2013-01-03  FCN        17.9  17.8   17.4  17.9  17.3           0.6
# 7467 2013-01-04  FCN        17.4  17.6   17.5  17.8  17.4           0.4
# 7465 2013-01-07  FCN        17.5  17.5   17.4  17.8  17.4           0.4
# 7463 2013-01-08  FCN        17.4  17.4   17.9  18.0  17.4           0.6

# %%
HHV.head()
# Out:
#                  date code  basicPrice  open  close  high   low  price_spread  \
# date
# 2015-12-18 2015-12-18  HHV        10.5  10.5   10.5  10.5  10.5           0.0
# 2015-12-21 2015-12-21  HHV        10.5  14.7   14.7  14.7  14.7           0.0
# 2015-12-22 2015-12-22  HHV        14.7  14.7   14.7  14.7  14.7           0.0
# 2015-12-23 2015-12-23  HHV        14.7  14.7   14.7  14.7  14.7           0.0
# 2015-12-24 2015-12-24  HHV        14.7  14.7   14.7  14.7  14.7           0.0
#
#                Fitted
# date
# 2015-12-18   0.000000
# 2015-12-21  10.499998
# 2015-12-22  10.499999
# 2015-12-23  13.761814
# 2015-12-24  14.330497

# %%
HHV = HHV[['basicPrice']]
HHV.columns = ['HHV_price']

# %%
VCG.set_index(VCG['date'], inplace=True)
VCG = VCG[['basicPrice']]
VCG.columns = ['VCG_price']

# %%
FCN.set_index(FCN['date'], inplace=True)
FCN = FCN[['basicPrice']]
FCN.columns = ['FCN_price']

# %%
HHV = HHV['2020-01-01':]

# %%
VCG = VCG['2020-01-01':]

# %%
FCN = FCN['2020-01-01':]

# %%
data_new = pd.merge(FCN, HHV, left_index=True, right_index=True, how='outer')
data_new.head()
# Out:
#             FCN_price  HHV_price
# date
# 2020-01-02       9.90       12.7
# 2020-01-03      10.10       12.7
# 2020-01-06      10.20       12.7
# 2020-01-07      10.20       11.0
# 2020-01-08      10.15       11.0

# %%
data_new = pd.merge(data_new, VCG, left_index=True, right_index=True, how='outer')
data_new.head()
# Out:
#             FCN_price  HHV_price  VCG_price
# date
# 2020-01-02       9.90       12.7       26.9
# 2020-01-03      10.10       12.7       26.5
# 2020-01-06      10.20       12.7       26.1
# 2020-01-07      10.20       11.0       25.9
# 2020-01-08      10.15       11.0       25.8

# %%
data_new.columns = ['FCN', 'HHV', 'VCG']

# %%
#take price on 02-01-2020 as a benchmark 
ret = data_new/data_new.iloc[0]*100
ret.head()
# Out:
#                    FCN         HHV         VCG
# date
# 2020-01-02  100.000000  100.000000  100.000000
# 2020-01-03  102.020202  100.000000   98.513011
# 2020-01-06  103.030303  100.000000   97.026022
# 2020-01-07  103.030303   86.614173   96.282528
# 2020-01-08  102.525253   86.614173   95.910781

# %%
ret.plot(figsize=(10,6), title='Price of three stock');

# %%
#calculate return daily
log_ret = np.log(data_new/data_new.shift(1))
print(log_ret.head())
#histogram return daily
log_ret.hist(bins=40, figsize=(10, 8));
# Out:
#                  FCN       HHV       VCG
# date
# 2020-01-02       NaN       NaN       NaN
# 2020-01-03  0.020001  0.000000 -0.014982
# 2020-01-06  0.009852  0.000000 -0.015209
# 2020-01-07  0.000000 -0.143707 -0.007692
# 2020-01-08 -0.004914  0.000000 -0.003868

# %%
#Annualized mean returns
log_ret.mean() * 252
# Out:
# FCN    0.195302
# HHV    0.090356
# VCG    0.036108
# dtype: float64

# %%
#Annualized covariance matrix
log_ret.cov() * 252
# Out:
#           FCN       HHV       VCG
# FCN  0.258412  0.122950  0.127036
# HHV  0.122950  0.453561  0.104385
# VCG  0.127036  0.104385  0.187322

# %%
#correlation stocks
log_ret.corr()
# Out:
#           FCN       HHV       VCG
# FCN  1.000000  0.361765  0.575559
# HHV  0.361765  1.000000  0.360107
# VCG  0.575559  0.360107  1.000000

# %%
#create an array for weight of stock sum of weight equal 1
noa = 3
weights = np.random.random(noa)
weights /= np.sum(weights)

# %%
#Annualized portfolio return given the portfolio weights.
np.sum(log_ret.mean() * weights) * 252
# Out:
# 0.06786484389106938

# %%
#Annualized portfolio variance given the portfolio weights
np.dot(weights.T, np.dot(log_ret.cov() * 252, weights))
# Out:
# 0.16840936991683517

# %%
#Annualized portfolio volatility given the portfolio weights
math.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
# Out:
# 0.4103771069599706

# %%
#define function to calculate portfolio 
def port_ret(weights):
    return np.sum(log_ret.mean() * weights) * 252
def port_vol(weights):
    return np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

# %%
prets = []
pvols = []
for p in range (10000):
    weights = np.random.random(noa)
    weights /= np.sum(weights)
    prets.append(port_ret(weights))
    pvols.append(port_vol(weights))
prets = np.array(prets)
pvols = np.array(pvols)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pvols, prets, c=prets / pvols,
marker='o', cmap='coolwarm')
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe ratio');

# %% [markdown]
# Optimal Portfolios

# %%
import scipy.optimize as sco

# %%
#Function to be minimized.
def min_func_sharpe(weights):
    return -port_ret(weights) / port_vol(weights)

# %%
#Equality constraint.
cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

# %%
#Bounds for the parameters
bnds = tuple((0, 1) for x in range(noa))

# %%
#Equal weights vector.
eweights = np.array(noa * [1. / noa,])
eweights
# Out:
# array([0.33333333, 0.33333333, 0.33333333])

# %%
min_func_sharpe(eweights)
# Out:
# -0.25374132206375066

# %%
optv = sco.minimize(port_vol, eweights,
                    method='SLSQP', bounds=bnds,
                    constraints=cons)
optv
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 0.3998794308272277
#        x: [ 2.546e-01  1.446e-01  6.008e-01]
#      nit: 5
#      jac: [ 3.999e-01  3.991e-01  4.001e-01]
#     nfev: 20
#     njev: 5

# %%
optv['x'].round(3)
# Out:
# array([0.255, 0.145, 0.601])

# %%
port_vol(optv['x']).round(3)
# Out:
# 0.4

# %%
port_ret(optv['x']).round(3)
# Out:
# 0.084

# %%
port_ret(optv['x']) / port_vol(optv['x'])
# Out:
# 0.21128394409730145

# %%
# %%time
opts = sco.minimize(min_func_sharpe, eweights,
method='SLSQP', bounds=bnds,
constraints=cons)
# Out:
# CPU times: total: 250 ms
# Wall time: 268 ms

# %%
opts
# Out:
#  message: Positive directional derivative for linesearch
#  success: False
#   status: 8
#      fun: -0.3841929840066537
#        x: [ 1.000e+00  1.446e-14  0.000e+00]
#      nit: 13
#      jac: [-3.725e-09  5.049e-03  1.178e-01]
#     nfev: 96
#     njev: 9

# %%
opts['x'].round(3)
# Out:
# array([1., 0., 0.])

# %%
cons = ({'type': 'eq', 'fun': lambda x: port_ret(x) - tret},
        {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
bnds = tuple((0, 1) for x in weights)

# %%
# %%time
trets = np.linspace(0.05, 0.2, 50)
tvols = []
for tret in trets:
    res = sco.minimize(port_vol, eweights, method='SLSQP',
                    bounds=bnds, constraints=cons)
    tvols.append(res['fun'])
tvols = np.array(tvols)
# Out:
# CPU times: total: 1.61 s
# Wall time: 2.1 s

# %%
plt.figure(figsize=(10, 6))
plt.scatter(pvols, prets, c=prets / pvols,
marker='.', alpha=0.8, cmap='coolwarm')
plt.plot(tvols, trets, 'b', lw=4.0)
plt.plot(port_vol(opts['x']), port_ret(opts['x']),
'y*', markersize=15.0)
plt.plot(port_vol(optv['x']), port_ret(optv['x']),
'r*', markersize=15.0)
plt.xlabel('expected volatility')
plt.ylabel('expected return')
plt.colorbar(label='Sharpe ratio')

# %%
import scipy.interpolate as sci

# %%
ind = np.argmin(tvols)
evols = tvols[ind:]
erets = trets[ind:]

# %%
tck = sci.splrep(evols, erets)

# %%
def f(x):
    ''' Efficient frontier function (splines approximation). '''
    return sci.splev(x, tck, der=0)
def df(x):
    ''' First derivative of efficient frontier function. '''
    return sci.splev(x, tck, der=1)

# %%
def equations(p, rf=0.01):
    eq1 = rf - p[0]
    eq2 = rf + p[1] * p[2] - f(p[2])
    eq3 = p[1] - df(p[2])
    return eq1, eq2, eq3

# %%
opt = sco.fsolve(equations, [0.01, 0.5, 0.15])

# %%
opt
# Out:
# array([0.01      , 2.67422667, 0.40102417])

# %%
np.round(equations(opt), 6)
# Out:
# array([ 0.      ,  0.98674 , -0.395713])

# %%
cons = ({'type': 'eq', 'fun': lambda x: port_ret(x) - f(opt[2])},
{'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
res = sco.minimize(port_vol, eweights, method='SLSQP',
bounds=bnds, constraints=cons)

# %%
res['x'].round(3)
# Out:
# array([0.326, 0.143, 0.532])

# %%
port_ret(res['x'])
# Out:
# 0.0956893265231326

# %%
port_vol(res['x'])
# Out:
# 0.40104888660299565

# %%
port_ret(res['x']) / port_vol(res['x'])
# Out:
# 0.23859766158098553
